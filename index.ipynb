# %% [markdown]
#  ![](fig/python-logo.png)
#
# ### Master 2 DUAS Unistra,  2018-2019
#
# ***
#
# # Programmer en Python
# ***
#
#
# ## Contenu
#
# <br>
# <style>
#     table {
#         display: inline;
#     }
#     table, tr, th, td {
#         border: 0 !important;
#     }
#     th {
#         font-weight: normal !important;
#         font-size: 110%;
#     }
#     td {
#         font-size: 130%;
#     }
# </style>
#
# <table>
#   <tr>
#     <th></th>
#     <th>Html</th>
#     <th>Diaporama</th>
#     <th>Archive</th>
#     <th>Colaboratory</th>
#   </tr>
#   <tr>
#     <td>Les généralités</td>
#     <td><a href="01-generalites.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#     <td><a href="01-generalites.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#     <td><a href="01-generalites.zip"><img width="35" src="fig/download.svg"></a></td>
#     <td><a href="https://colab.research.google.com/github/boileaum/cours-python/blob/master/01-generalites.ipynb"><img width="35" src="fig/favicon-colab.ico"></a><td>
#   </tr>
#   <tr>
#     <td>Le langage (1)</td>
#     <td><a href="02-langage.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#     <td><a href="02-langage.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#     <td><a href="02-langage.zip"><img width="35" src="fig/download.svg"></a></td>
#     <td><a href="https://colab.research.google.com/github/boileaum/cours-python/blob/master/02-langage.ipynb"><img width="35" src="fig/favicon-colab.ico"></a><td>
#   </tr>
#   <tr>
#       <td>Le langage (2)</td>
#       <td><a href="03-langage.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#       <td><a href="03-langage.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#   </tr>
#   <tr>
#       <td>Numpy</td>
#       <td><a href="04-numpy.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#       <td><a href="04-numpy.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#   </tr>
#   <tr>
#       <td>Microprojet</td>
#       <td><a href="04-numpy.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#       <td><a href="04-numpy.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#   </tr>
#   <tr>
#       <td>Le langage (3)</td>
#       <td><a href="06-langage.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#       <td><a href="06-langage.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#   </tr>
#   <tr>
#       <td>Pandas</td>
#       <td><a href="07-pandas.html"><img width="25" src="fig/favicon-notebook.ico"></a></td>
#       <td><a href="07-pandas.slides.html"><img width="35" src="fig/slideshow.png"></a></td>
#   </tr>
# </table>
#
# <br>
#
# <style>
#   td#bottom {
#     font-size: 100%;
#     font-weight: bold;
#   }
# </style>
#
# <table id="bottom">
#   <tr>
#       <td id="bottom">Exécuter</td>
#       <td><a href="https://mybinder.org/v2/gh/boileaum/cours-python/master"><img src="https://mybinder.org/badge.svg"></a></td>
#   </tr>
#   <tr>
#       <td id="bottom">Livre</td>
#       <td id="bottom"><a href="cours-python.pdf"><img width="30" src="fig/Adobe_PDF_icon.svg"></a></td>
#   </tr>
#   <tr>
#       <td id="bottom">Sources</td>
#       <td><a href="https://gitlab.math.unistra.fr/mm2act/cours-python"><img width="30" src="fig/GitLab_Logo.svg"></a></td>
#   </tr>
# </table>
#
# ***
# Matthieu Boileau - [matthieu.boileau@math.unistra.fr](mailto: matthieu.boileau@math.unistra.fr)
# Vincent Legoll - [vincentlegoll@gmail.com](mailto: vincent.legoll@gmail.com)
#
# *Contenu mis à disposition sous licence [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0)*
